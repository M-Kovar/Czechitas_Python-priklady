# %% [markdown]
# # 01: Vozidla hromadné dopravy IDS JMK
#
# Na https://mapa.idsjmk.cz/ můžeš sledovat aktuální polohu a další informace o vozidlech Integrovaného dopravního systému Jihomoravského kraje. Data si zkusíme analyzovat:
#
# - Otevři si https://mapa.idsjmk.cz/api/vehicles.json v prohlížeči a podívej se na strukturu dat, ať víš, do čeho jdeš:).
#
# - Načti si data z API na adrese https://mapa.idsjmk.cz/api/vehicles.json pomocí modulu `requests`. (Kdyby nefungovalo API, využij přiložený soubor `vehicles.json`.) *Pozor, načtení pomocí `response.json()` vrací chybu kvůli skrytým nestandardním znakům. Proto využij modul `json`, kterým zpracuješ vrácenou response příkazem `data = json.loads(response.content.decode("utf-8-sig"))`.*
#
# - Zobraz datum a čas vytvoření souboru ve formátu jako např. "Datum: 2024-12-31, čas: 08:30:00". Data najdeš pod klíčem 'LastUpdate'. Využij jednoduchý slicing (indexování) řetězce.
#
# Následující úkoly můžeš řešit pomocí slovníků v pythonu nebo pomocí pandas. Ideální bude vyzkoušet obojí, ale potom si radši pro každé řešení vytvoř nový soubor nebo novou buňku v jupyter notebooku, ať se to nemíchá.
#
# *Pro pandas variantu řešení načti jako DataFrame pouze podslovník uložený pod klíčem 'Vehicles'. Bude se hodit metoda `DataFrame.from_dict()`.*
#
# 1. Spočítej následující hodnoty a vypiš výsledek *(vyzkoušej si všechny nebo jen některé body)*:
# - Počet všech vozidel
# - Počet vozidel na pauze ('IsInactive' je `True`).
# - Počet vozidel se zpožděním ('Delay') větším než 5 minut. Kolik je to procent ze všech vozidel?
# - Průměr zpoždění všech vozidel (včetně těch pod 5 minut).
# - Počet nízkopodlažních ('LF' je `True`) regionálních vlaků  ('LineName' obsahuje 'R' nebo 'S'). Pro pandas variantu řešení se na 'LineName' může hodit metoda `str.contains()`.
#
# 2. Spočítej zvlášť ~~tramvaje~~ šaliny ('LineID' je 1-12), trolejbusy ('LineID' je 20-39) a městské autobusy ('LineID' je 40-99). Aktivní a neaktivní není potřeba rozlišovat. *Pro pandas variantu řešení můžeš využít složené podmínky nebo metodu `between()`.* Výsledek vypiš a ulož do souboru `pocty_vozidel_brno.json` jako slovník/JSON s klíči "pocet_tramvaji", "pocet_trolejbusu" a "pocet_autobusu" a odpovídajícími hodnotami.
#
# Pokud pracuješ s aktuálními daty, můžeš počty porovnat s těmi na adrese https://mapa.idsjmk.cz/ (nemusí sedět úplně přesně kvůli výlukovým linkám, ale ty neuvažujme).
#
# *Podrobnější popis položek JSONu najdeš např. na [data.brno.cz/...](https://data.brno.cz/datasets/mestobrno::polohy-vozidel-hromadn%C3%A9-dopravy-public-transit-positional-data/about), kde se nachází i databáze s historií dat.*

# %%
import requests
import json

url = "https://mapa.idsjmk.cz/api/vehicles.json"

response = requests.get(url)
data = json.loads(response.content.decode("utf-8-sig"))
data
# Out:
# {'LastUpdate': '2024-04-24T21:00:32.3781021+02:00',
#  'Vehicles': [{'ID': 1922,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.192734,
#    'Lng': 16.572811,
#    'Bearing': -1,
#    'LineID': 2,
#    'LineName': '2',
#    'RouteID': 1505,
#    'ServiceId': 212,
#    'Course': '00212',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 9410,
#    'FinalStopID': 1343,
#    'FinalStopName': 'Lipová',
#    'IsInactive': True},
#   {'ID': 21571,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.853413,
#    'Lng': 17.109982,
#    'Bearing': 45,
#    'LineID': 901,
#    'LineName': '901',
#    'RouteID': 75,
#    'ServiceId': 90301,
#    'Course': '90301',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 19019,
#    'FinalStopID': 19008,
#    'FinalStopName': 'Hodonín, nem.láz.',
#    'IsInactive': False},
#   {'ID': 21136,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.755608,
#    'Lng': 16.850769,
#    'Bearing': 225,
#    'LineID': 571,
#    'LineName': '571',
#    'RouteID': 23,
#    'ServiceId': 57101,
#    'Course': '57101',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15745,
#    'FinalStopID': 15801,
#    'FinalStopName': 'Valtice, aut. st.',
#    'IsInactive': False},
#   {'ID': 1925,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.191319,
#    'Lng': 16.61224,
#    'Bearing': 45,
#    'LineID': 2,
#    'LineName': '2',
#    'RouteID': 1268,
#    'ServiceId': 206,
#    'Course': '00206',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1146,
#    'FinalStopID': 1611,
#    'FinalStopName': 'Stará osada',
#    'IsInactive': False},
#   {'ID': 1094,
#    'IDB': 1523,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.231365,
#    'Lng': 16.577042,
#    'Bearing': 315,
#    'LineID': 12,
#    'LineName': '12',
#    'RouteID': 1306,
#    'ServiceId': 1221,
#    'Course': '01221',
#    'LF': True,
#    'Delay': 2,
#    'LastStopID': 1659,
#    'FinalStopID': 1659,
#    'FinalStopName': 'Technologický park',
#    'IsInactive': False},
#   {'ID': 21486,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.877708,
#    'Lng': 16.979494,
#    'Bearing': 45,
#    'LineID': 913,
#    'LineName': '913',
#    'RouteID': 26,
#    'ServiceId': 91302,
#    'Course': '91302',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 19106,
#    'FinalStopID': 19001,
#    'FinalStopName': 'Hodonín, a.n.',
#    'IsInactive': False},
#   {'ID': 1737,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.202198,
#    'Lng': 16.582056,
#    'Bearing': 0,
#    'LineID': 4,
#    'LineName': '4',
#    'RouteID': 1286,
#    'ServiceId': 412,
#    'Course': '00412',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1371,
#    'FinalStopID': 1668,
#    'FinalStopName': 'Tomkovo náměstí',
#    'IsInactive': False},
#   {'ID': 21181,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.038403,
#    'Lng': 16.91688,
#    'Bearing': 0,
#    'LineID': 610,
#    'LineName': '610',
#    'RouteID': 87,
#    'ServiceId': 61002,
#    'Course': '61002',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16302,
#    'FinalStopID': 16301,
#    'FinalStopName': 'Dambořice',
#    'IsInactive': False},
#   {'ID': 21395,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.373035,
#    'Lng': 16.665741,
#    'Bearing': 90,
#    'LineID': 223,
#    'LineName': '223',
#    'RouteID': 59,
#    'ServiceId': 22201,
#    'Course': '22201',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 12392,
#    'FinalStopID': 12346,
#    'FinalStopName': 'Blansko, Češkovice',
#    'IsInactive': False},
#   {'ID': 7814,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.212933,
#    'Lng': 16.560385,
#    'Bearing': 270,
#    'LineID': 52,
#    'LineName': '52',
#    'RouteID': 1166,
#    'ServiceId': 5209,
#    'Course': '05209',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 0,
#    'FinalStopID': 1378,
#    'FinalStopName': 'Mendlovo náměstí',
#    'IsInactive': False},
#   {'ID': 2669,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.22168,
#    'Lng': 16.585953,
#    'Bearing': 45,
#    'LineID': 67,
#    'LineName': '67',
#    'RouteID': 1125,
#    'ServiceId': 50014,
#    'Course': '50014',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 1567,
#    'FinalStopID': 1146,
#    'FinalStopName': 'Hlavní nádraží',
#    'IsInactive': False},
#   {'ID': 21121,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.18885,
#    'Lng': 16.613403,
#    'Bearing': 45,
#    'LineID': 502,
#    'LineName': 'CTP',
#    'RouteID': 100,
#    'ServiceId': 50202,
#    'Course': '50202',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15103,
#    'FinalStopID': 1716,
#    'FinalStopName': 'Úzká',
#    'IsInactive': False},
#   {'ID': 21032,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 2,
#    'Lat': 49.16077,
#    'Lng': 16.638386,
#    'Bearing': 135,
#    'LineID': 74,
#    'LineName': '74',
#    'RouteID': 255,
#    'ServiceId': 4843,
#    'Course': '04843',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1533,
#    'FinalStopID': 16156,
#    'FinalStopName': 'Újezd u Brna, MěÚ',
#    'IsInactive': False},
#   {'ID': 21074,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.357426,
#    'Lng': 17.017723,
#    'Bearing': 315,
#    'LineID': 756,
#    'LineName': '756',
#    'RouteID': 29,
#    'ServiceId': 75601,
#    'Course': '75601',
#    'LF': True,
#    'Delay': 2,
#    'LastStopID': 17525,
#    'FinalStopID': 17603,
#    'FinalStopName': 'Podivice',
#    'IsInactive': False},
#   {'ID': 1090,
#    'IDB': 1597,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.199692,
#    'Lng': 16.608025,
#    'Bearing': 0,
#    'LineID': 1,
#    'LineName': '1',
#    'RouteID': 1304,
#    'ServiceId': 133,
#    'Course': '00133',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1397,
#    'FinalStopID': 1553,
#    'FinalStopName': 'Řečkovice',
#    'IsInactive': False},
#   {'ID': 21493,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.007168,
#    'Lng': 16.074934,
#    'Bearing': 135,
#    'LineID': 812,
#    'LineName': '812',
#    'RouteID': 64,
#    'ServiceId': 44202,
#    'Course': '44202',
#    'LF': False,
#    'Delay': 0,
#    'LastStopID': 14723,
#    'FinalStopID': 18009,
#    'FinalStopName': 'Znojmo, a.n.',
#    'IsInactive': False},
#   {'ID': 21899,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.910847,
#    'Lng': 17.418867,
#    'Bearing': 270,
#    'LineID': 930,
#    'LineName': '930',
#    'RouteID': 38,
#    'ServiceId': 93002,
#    'Course': '93002',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 19417,
#    'FinalStopID': 19316,
#    'FinalStopName': 'Veselí n/M., ž.s.',
#    'IsInactive': False},
#   {'ID': 21903,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.139526,
#    'Lng': 16.880417,
#    'Bearing': 180,
#    'LineID': 631,
#    'LineName': '631',
#    'RouteID': 30,
#    'ServiceId': 63102,
#    'Course': '63102',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16332,
#    'FinalStopID': 16313,
#    'FinalStopName': 'Kobeřice, pohos.',
#    'IsInactive': False},
#   {'ID': 21860,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.129543,
#    'Lng': 16.80938,
#    'Bearing': 315,
#    'LineID': 630,
#    'LineName': '630',
#    'RouteID': 44,
#    'ServiceId': 63002,
#    'Course': '63002',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16222,
#    'FinalStopID': 16333,
#    'FinalStopName': 'Slavkov u B., ž.s.',
#    'IsInactive': False},
#   {'ID': 7092,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.155174,
#    'Lng': 16.691406,
#    'Bearing': -1,
#    'LineID': 76,
#    'LineName': 'E76',
#    'RouteID': 1065,
#    'ServiceId': 7601,
#    'Course': '07601',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1337,
#    'FinalStopID': 1146,
#    'FinalStopName': 'Hlavní nádraží',
#    'IsInactive': False},
#   {'ID': 21091,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.535263,
#    'Lng': 16.606043,
#    'Bearing': 180,
#    'LineID': 254,
#    'LineName': '254',
#    'RouteID': 56,
#    'ServiceId': 27401,
#    'Course': '27401',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 12706,
#    'FinalStopID': 12635,
#    'FinalStopName': 'Boskovice, aut.st.',
#    'IsInactive': False},
#   {'ID': 7056,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.193081,
#    'Lng': 16.614412,
#    'Bearing': 180,
#    'LineID': 76,
#    'LineName': 'E76',
#    'RouteID': 1064,
#    'ServiceId': 7605,
#    'Course': '07605',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 1146,
#    'FinalStopID': 1337,
#    'FinalStopName': 'Letiště Tuřany',
#    'IsInactive': False},
#   {'ID': 21434,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.791168,
#    'Lng': 17.016508,
#    'Bearing': 180,
#    'LineID': 572,
#    'LineName': '572',
#    'RouteID': 78,
#    'ServiceId': 57202,
#    'Course': '57202',
#    'LF': False,
#    'Delay': 1,
#    'LastStopID': 19126,
#    'FinalStopID': 15729,
#    'FinalStopName': 'Břeclav, a.n.',
#    'IsInactive': False},
#   {'ID': 1569,
#    'IDB': 1531,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.192829,
#    'Lng': 16.571077,
#    'Bearing': -1,
#    'LineID': 6,
#    'LineName': '6',
#    'RouteID': 1506,
#    'ServiceId': 613,
#    'Course': '00613',
#    'LF': False,
#    'Delay': 0,
#    'LastStopID': 9410,
#    'FinalStopID': 1343,
#    'FinalStopName': 'Lipová',
#    'IsInactive': True},
#   {'ID': 7820,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.176498,
#    'Lng': 16.525772,
#    'Bearing': 45,
#    'LineID': 69,
#    'LineName': '69',
#    'RouteID': 1115,
#    'ServiceId': 6903,
#    'Course': '06903',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1037,
#    'FinalStopID': 1699,
#    'FinalStopName': 'Univerzitní kampus',
#    'IsInactive': False},
#   {'ID': 21779,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.297436,
#    'Lng': 16.978985,
#    'Bearing': 180,
#    'LineID': 750,
#    'LineName': '750',
#    'RouteID': 70,
#    'ServiceId': 75002,
#    'Course': '75002',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 17445,
#    'FinalStopID': 17423,
#    'FinalStopName': 'Vyškov, a.n.',
#    'IsInactive': False},
#   {'ID': 21175,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.897961,
#    'Lng': 17.316128,
#    'Bearing': 180,
#    'LineID': 910,
#    'LineName': '910',
#    'RouteID': 13,
#    'ServiceId': 91106,
#    'Course': '91106',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 19205,
#    'FinalStopID': 19316,
#    'FinalStopName': 'Veselí n/M., ž.s.',
#    'IsInactive': False},
#   {'ID': 1595,
#    'IDB': 1564,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.192593,
#    'Lng': 16.572769,
#    'Bearing': 315,
#    'LineID': 6,
#    'LineName': '6',
#    'RouteID': 1516,
#    'ServiceId': 611,
#    'Course': '00611',
#    'LF': False,
#    'Delay': 0,
#    'LastStopID': 9410,
#    'FinalStopID': 1343,
#    'FinalStopName': 'Lipová',
#    'IsInactive': False},
#   {'ID': 21308,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.474548,
#    'Lng': 16.720184,
#    'Bearing': 180,
#    'LineID': 261,
#    'LineName': '261',
#    'RouteID': 26,
#    'ServiceId': 26101,
#    'Course': '26101',
#    'LF': False,
#    'Delay': 0,
#    'LastStopID': 12627,
#    'FinalStopID': 12635,
#    'FinalStopName': 'Boskovice, aut.st.',
#    'IsInactive': False},
#   {'ID': 21773,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.852982,
#    'Lng': 16.058334,
#    'Bearing': 90,
#    'LineID': 801,
#    'LineName': '801',
#    'RouteID': 50,
#    'ServiceId': 80403,
#    'Course': '80403',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 18008,
#    'FinalStopID': 18013,
#    'FinalStopName': 'Hradiště, sýpka',
#    'IsInactive': False},
#   {'ID': 21656,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.058868,
#    'Lng': 17.215178,
#    'Bearing': 225,
#    'LineID': 666,
#    'LineName': '666',
#    'RouteID': 46,
#    'ServiceId': 66601,
#    'Course': '66601',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16851,
#    'FinalStopID': 16608,
#    'FinalStopName': 'Kyjov, aut. st.',
#    'IsInactive': False},
#   {'ID': 21369,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.515678,
#    'Lng': 16.618486,
#    'Bearing': 315,
#    'LineID': 253,
#    'LineName': '253',
#    'RouteID': 25,
#    'ServiceId': 25301,
#    'Course': '25301',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 12679,
#    'FinalStopID': 12919,
#    'FinalStopName': 'Velké Opatovice,a.s.',
#    'IsInactive': False},
#   {'ID': 21971,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.383297,
#    'Lng': 16.513176,
#    'Bearing': 270,
#    'LineID': 332,
#    'LineName': '332',
#    'RouteID': 35,
#    'ServiceId': 33201,
#    'Course': '33201',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 13304,
#    'FinalStopID': 12421,
#    'FinalStopName': 'Rašov, hostinec',
#    'IsInactive': False},
#   {'ID': 1708,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.247112,
#    'Lng': 16.57893,
#    'Bearing': 135,
#    'LineID': 1,
#    'LineName': '1',
#    'RouteID': 1307,
#    'ServiceId': 50092,
#    'Course': '50092',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1553,
#    'FinalStopID': 1102,
#    'FinalStopName': 'Bystrc, Ečerova',
#    'IsInactive': False},
#   {'ID': 21402,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.212448,
#    'Lng': 16.407234,
#    'Bearing': 135,
#    'LineID': 402,
#    'LineName': '402',
#    'RouteID': 60,
#    'ServiceId': 40201,
#    'Course': '40201',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 14244,
#    'FinalStopID': 1429,
#    'FinalStopName': 'Nemocnice Bohunice',
#    'IsInactive': False},
#   {'ID': 21139,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.263454,
#    'Lng': 17.056095,
#    'Bearing': 0,
#    'LineID': 752,
#    'LineName': '752',
#    'RouteID': 26,
#    'ServiceId': 75201,
#    'Course': '75201',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 17507,
#    'FinalStopID': 17423,
#    'FinalStopName': 'Vyškov, a.n.',
#    'IsInactive': False},
#   {'ID': 21093,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.043747,
#    'Lng': 16.999914,
#    'Bearing': 315,
#    'LineID': 655,
#    'LineName': '655',
#    'RouteID': 91,
#    'ServiceId': 65502,
#    'Course': '65502',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16525,
#    'FinalStopID': 16437,
#    'FinalStopName': 'Násedlovice, mlýn',
#    'IsInactive': False},
#   {'ID': 21097,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.149475,
#    'Lng': 16.876179,
#    'Bearing': 270,
#    'LineID': 601,
#    'LineName': '601',
#    'RouteID': 43,
#    'ServiceId': 60101,
#    'Course': '60101',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16328,
#    'FinalStopID': 1696,
#    'FinalStopName': 'Brno, ÚAN Zvonařka',
#    'IsInactive': False},
#   {'ID': 21554,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.980721,
#    'Lng': 16.521919,
#    'Bearing': 270,
#    'LineID': 104,
#    'LineName': '104',
#    'RouteID': 27,
#    'ServiceId': 10404,
#    'Course': '10404',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15317,
#    'FinalStopID': 15775,
#    'FinalStopName': 'Hevlín, škola',
#    'IsInactive': False},
#   {'ID': 21848,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.468674,
#    'Lng': 16.586073,
#    'Bearing': 90,
#    'LineID': 257,
#    'LineName': '257',
#    'RouteID': 22,
#    'ServiceId': 25702,
#    'Course': '25702',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 12667,
#    'FinalStopID': 12633,
#    'FinalStopName': 'Boskovice, 17. list.',
#    'IsInactive': False},
#   {'ID': 3301,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.21394,
#    'Lng': 16.522469,
#    'Bearing': 225,
#    'LineID': 30,
#    'LineName': '30',
#    'RouteID': 1233,
#    'ServiceId': 3013,
#    'Course': '03013',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1062,
#    'FinalStopID': 1286,
#    'FinalStopName': 'Královo Pole, nádraží',
#    'IsInactive': False},
#   {'ID': 3302,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.217846,
#    'Lng': 16.575537,
#    'Bearing': 270,
#    'LineID': 36,
#    'LineName': '36',
#    'RouteID': 1172,
#    'ServiceId': 3401,
#    'Course': '03401',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 1352,
#    'FinalStopID': 1258,
#    'FinalStopName': 'Komín, sídliště',
#    'IsInactive': False},
#   {'ID': 2677,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.17942,
#    'Lng': 16.568668,
#    'Bearing': 90,
#    'LineID': 40,
#    'LineName': '40',
#    'RouteID': 1114,
#    'ServiceId': 4008,
#    'Course': '04008',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 1624,
#    'FinalStopID': 1624,
#    'FinalStopName': 'Studentská',
#    'IsInactive': False},
#   {'ID': 7010,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.206951,
#    'Lng': 16.663387,
#    'Bearing': 45,
#    'LineID': 57,
#    'LineName': '57',
#    'RouteID': 1238,
#    'ServiceId': 5707,
#    'Course': '05707',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1052,
#    'FinalStopID': 1132,
#    'FinalStopName': 'Lesná, Haškova',
#    'IsInactive': False},
#   {'ID': 1728,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.234074,
#    'Lng': 16.580835,
#    'Bearing': -1,
#    'LineID': 4,
#    'LineName': '4',
#    'RouteID': 1918,
#    'ServiceId': 402,
#    'Course': '00402',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 9430,
#    'FinalStopID': 1659,
#    'FinalStopName': 'Technologický park',
#    'IsInactive': True},
#   {'ID': 21042,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.048286,
#    'Lng': 16.31007,
#    'Bearing': 315,
#    'LineID': 164,
#    'LineName': '164',
#    'RouteID': 66,
#    'ServiceId': 16401,
#    'Course': '16401',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 14499,
#    'FinalStopID': 14016,
#    'FinalStopName': 'Loděnice, škola',
#    'IsInactive': False},
#   {'ID': 21219,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.037796,
#    'Lng': 16.321259,
#    'Bearing': 180,
#    'LineID': 440,
#    'LineName': '440',
#    'RouteID': 41,
#    'ServiceId': 44001,
#    'Course': '44001',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 14468,
#    'FinalStopID': 14479,
#    'FinalStopName': 'Mor. Krumlov, ž.s.',
#    'IsInactive': False},
#   {'ID': 21624,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.110161,
#    'Lng': 16.602924,
#    'Bearing': -1,
#    'LineID': 502,
#    'LineName': 'CTP',
#    'RouteID': 102,
#    'ServiceId': 50201,
#    'Course': '50201',
#    'LF': False,
#    'Delay': 0,
#    'LastStopID': 15105,
#    'FinalStopID': 1716,
#    'FinalStopName': 'Úzká',
#    'IsInactive': False},
#   {'ID': 21576,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.21471,
#    'Lng': 16.395374,
#    'Bearing': 90,
#    'LineID': 153,
#    'LineName': '153',
#    'RouteID': 112,
#    'ServiceId': 42101,
#    'Course': '42101',
#    'LF': False,
#    'Delay': 0,
#    'LastStopID': 14217,
#    'FinalStopID': 13265,
#    'FinalStopName': 'Vev. Bítýška, nám.',
#    'IsInactive': False},
#   {'ID': 21481,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.290768,
#    'Lng': 16.348154,
#    'Bearing': 135,
#    'LineID': 312,
#    'LineName': '312',
#    'RouteID': 55,
#    'ServiceId': 31203,
#    'Course': '31203',
#    'LF': True,
#    'Delay': 4,
#    'LastStopID': 13343,
#    'FinalStopID': 13124,
#    'FinalStopName': 'Kuřim, Prefa',
#    'IsInactive': False},
#   {'ID': 21872,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.108543,
#    'Lng': 16.731892,
#    'Bearing': 90,
#    'LineID': 611,
#    'LineName': '611',
#    'RouteID': 62,
#    'ServiceId': 61001,
#    'Course': '61001',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16157,
#    'FinalStopID': 16149,
#    'FinalStopName': 'Sokolnice, žel.st.',
#    'IsInactive': False},
#   {'ID': 7712,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.259132,
#    'Lng': 16.58016,
#    'Bearing': -1,
#    'LineID': 42,
#    'LineName': '42',
#    'RouteID': 1109,
#    'ServiceId': 4302,
#    'Course': '04302',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1189,
#    'FinalStopID': 1286,
#    'FinalStopName': 'Královo Pole, nádraží',
#    'IsInactive': True},
#   {'ID': 21828,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.19318,
#    'Lng': 16.754807,
#    'Bearing': 0,
#    'LineID': 701,
#    'LineName': '701',
#    'RouteID': 93,
#    'ServiceId': 70102,
#    'Course': '70102',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 16160,
#    'FinalStopID': 17202,
#    'FinalStopName': 'Hostěnice, chaty',
#    'IsInactive': False},
#   {'ID': 21622,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.431259,
#    'Lng': 16.578936,
#    'Bearing': 0,
#    'LineID': 301,
#    'LineName': '301',
#    'RouteID': 113,
#    'ServiceId': 30103,
#    'Course': '30103',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 12445,
#    'FinalStopID': 12767,
#    'FinalStopName': 'Olešnice, nám.',
#    'IsInactive': False},
#   {'ID': 22034,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.852322,
#    'Lng': 17.106861,
#    'Bearing': 270,
#    'LineID': 556,
#    'LineName': '556',
#    'RouteID': 405,
#    'ServiceId': 55601,
#    'Course': '55601',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 19013,
#    'FinalStopID': 15619,
#    'FinalStopName': 'Podivín, žel.st.',
#    'IsInactive': False},
#   {'ID': 2635,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.224129,
#    'Lng': 16.607063,
#    'Bearing': 270,
#    'LineID': 44,
#    'LineName': '44',
#    'RouteID': 1195,
#    'ServiceId': 5007,
#    'Course': '05007',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 1288,
#    'FinalStopID': 1696,
#    'FinalStopName': 'Brno, ÚAN Zvonařka',
#    'IsInactive': False},
#   {'ID': 1926,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.234425,
#    'Lng': 16.583838,
#    'Bearing': 45,
#    'LineID': 3,
#    'LineName': '3',
#    'RouteID': 1510,
#    'ServiceId': 202,
#    'Course': '00202',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1659,
#    'FinalStopID': 1659,
#    'FinalStopName': 'Technologický park',
#    'IsInactive': False},
#   {'ID': 21247,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.200272,
#    'Lng': 16.873657,
#    'Bearing': 45,
#    'LineID': 602,
#    'LineName': '602',
#    'RouteID': 101,
#    'ServiceId': 10704,
#    'Course': '10704',
#    'LF': False,
#    'Delay': 2,
#    'LastStopID': 17337,
#    'FinalStopID': 17335,
#    'FinalStopName': 'Rousínov, aut.st.',
#    'IsInactive': False},
#   {'ID': 21292,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.882385,
#    'Lng': 17.358452,
#    'Bearing': 180,
#    'LineID': 931,
#    'LineName': '931',
#    'RouteID': 28,
#    'ServiceId': 93101,
#    'Course': '93101',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 19205,
#    'FinalStopID': 19316,
#    'FinalStopName': 'Veselí n/M., ž.s.',
#    'IsInactive': False},
#   {'ID': 21981,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.182457,
#    'Lng': 16.700161,
#    'Bearing': 270,
#    'LineID': 602,
#    'LineName': '602',
#    'RouteID': 60,
#    'ServiceId': 60205,
#    'Course': '60205',
#    'LF': False,
#    'Delay': 0,
#    'LastStopID': 16130,
#    'FinalStopID': 1696,
#    'FinalStopName': 'Brno, ÚAN Zvonařka',
#    'IsInactive': False},
#   {'ID': 1620,
#    'IDB': 1589,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.192669,
#    'Lng': 16.572966,
#    'Bearing': -1,
#    'LineID': 6,
#    'LineName': '6',
#    'RouteID': 1512,
#    'ServiceId': 609,
#    'Course': '00609',
#    'LF': False,
#    'Delay': 0,
#    'LastStopID': 9410,
#    'FinalStopID': 1343,
#    'FinalStopName': 'Lipová',
#    'IsInactive': True},
#   {'ID': 21239,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.199253,
#    'Lng': 16.71718,
#    'Bearing': 0,
#    'LineID': 151,
#    'LineName': '151',
#    'RouteID': 134,
#    'ServiceId': 15101,
#    'Course': '15101',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 16118,
#    'FinalStopID': 1362,
#    'FinalStopName': 'Mariánské údolí',
#    'IsInactive': False},
#   {'ID': 21388,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.214027,
#    'Lng': 17.030355,
#    'Bearing': 225,
#    'LineID': 156,
#    'LineName': '156',
#    'RouteID': 76,
#    'ServiceId': 64301,
#    'Course': '64301',
#    'LF': True,
#    'Delay': 11,
#    'LastStopID': 16417,
#    'FinalStopID': 17423,
#    'FinalStopName': 'Vyškov, a.n.',
#    'IsInactive': False},
#   {'ID': 21551,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.34269,
#    'Lng': 16.420961,
#    'Bearing': 45,
#    'LineID': 335,
#    'LineName': '335',
#    'RouteID': 34,
#    'ServiceId': 33501,
#    'Course': '33501',
#    'LF': False,
#    'Delay': 2,
#    'LastStopID': 13320,
#    'FinalStopID': 13334,
#    'FinalStopName': 'Tišnov, žel.st.',
#    'IsInactive': False},
#   {'ID': 22027,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.91061,
#    'Lng': 17.161633,
#    'Bearing': 0,
#    'LineID': 664,
#    'LineName': '664',
#    'RouteID': 45,
#    'ServiceId': 66401,
#    'Course': '66401',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 19009,
#    'FinalStopID': 16608,
#    'FinalStopName': 'Kyjov, aut. st.',
#    'IsInactive': False},
#   {'ID': 21877,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.147728,
#    'Lng': 17.001879,
#    'Bearing': 225,
#    'LineID': 156,
#    'LineName': '156',
#    'RouteID': 19,
#    'ServiceId': 15601,
#    'Course': '15601',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16435,
#    'FinalStopID': 16401,
#    'FinalStopName': 'Bučovice, aut. st.',
#    'IsInactive': False},
#   {'ID': 21009,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.839153,
#    'Lng': 16.912373,
#    'Bearing': 315,
#    'LineID': 556,
#    'LineName': '556',
#    'RouteID': 85,
#    'ServiceId': 55503,
#    'Course': '55503',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 15611,
#    'FinalStopID': 15619,
#    'FinalStopName': 'Podivín, žel.st.',
#    'IsInactive': False},
#   {'ID': 7020,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.157635,
#    'Lng': 16.69611,
#    'Bearing': -1,
#    'LineID': 77,
#    'LineName': '77',
#    'RouteID': 1157,
#    'ServiceId': 7711,
#    'Course': '07711',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1334,
#    'FinalStopID': 1716,
#    'FinalStopName': 'Úzká',
#    'IsInactive': True},
#   {'ID': 21756,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.357906,
#    'Lng': 16.515949,
#    'Bearing': 315,
#    'LineID': 321,
#    'LineName': '321',
#    'RouteID': 28,
#    'ServiceId': 32101,
#    'Course': '32101',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 13318,
#    'FinalStopID': 13209,
#    'FinalStopName': 'Drásov, náměstí',
#    'IsInactive': False},
#   {'ID': 7718,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.203915,
#    'Lng': 16.513721,
#    'Bearing': 135,
#    'LineID': 52,
#    'LineName': '52',
#    'RouteID': 1162,
#    'ServiceId': 5202,
#    'Course': '05202',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 1267,
#    'FinalStopID': 1378,
#    'FinalStopName': 'Mendlovo náměstí',
#    'IsInactive': False},
#   {'ID': 21118,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.898651,
#    'Lng': 17.315842,
#    'Bearing': 0,
#    'LineID': 910,
#    'LineName': '910',
#    'RouteID': 16,
#    'ServiceId': 91104,
#    'Course': '91104',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 19205,
#    'FinalStopID': 19001,
#    'FinalStopName': 'Hodonín, a.n.',
#    'IsInactive': False},
#   {'ID': 2684,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.181797,
#    'Lng': 16.658512,
#    'Bearing': 90,
#    'LineID': 77,
#    'LineName': '77',
#    'RouteID': 1152,
#    'ServiceId': 8404,
#    'Course': '08404',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1665,
#    'FinalStopID': 1581,
#    'FinalStopName': 'Areál Slatina',
#    'IsInactive': False},
#   {'ID': 21468,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.777332,
#    'Lng': 17.006752,
#    'Bearing': 45,
#    'LineID': 572,
#    'LineName': '572',
#    'RouteID': 77,
#    'ServiceId': 57201,
#    'Course': '57201',
#    'LF': True,
#    'Delay': 2,
#    'LastStopID': 15845,
#    'FinalStopID': 19001,
#    'FinalStopName': 'Hodonín, a.n.',
#    'IsInactive': False},
#   {'ID': 2661,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.204964,
#    'Lng': 16.666788,
#    'Bearing': 135,
#    'LineID': 78,
#    'LineName': '78',
#    'RouteID': 1125,
#    'ServiceId': 7812,
#    'Course': '07812',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 1383,
#    'FinalStopID': 1581,
#    'FinalStopName': 'Areál Slatina',
#    'IsInactive': False},
#   {'ID': 21989,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.051037,
#    'Lng': 16.945835,
#    'Bearing': 90,
#    'LineID': 660,
#    'LineName': '660',
#    'RouteID': 41,
#    'ServiceId': 66004,
#    'Course': '66004',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16442,
#    'FinalStopID': 16301,
#    'FinalStopName': 'Dambořice',
#    'IsInactive': False},
#   {'ID': 1760,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.201546,
#    'Lng': 16.668285,
#    'Bearing': 270,
#    'LineID': 8,
#    'LineName': '8',
#    'RouteID': 1303,
#    'ServiceId': 826,
#    'Course': '00826',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1438,
#    'FinalStopID': 1429,
#    'FinalStopName': 'Nemocnice Bohunice',
#    'IsInactive': False},
#   {'ID': 21559,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.84663,
#    'Lng': 16.058218,
#    'Bearing': 45,
#    'LineID': 817,
#    'LineName': '817',
#    'RouteID': 119,
#    'ServiceId': 81701,
#    'Course': '81701',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 18009,
#    'FinalStopID': 18251,
#    'FinalStopName': 'Čížov',
#    'IsInactive': False},
#   {'ID': 7734,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.249878,
#    'Lng': 16.581673,
#    'Bearing': 0,
#    'LineID': 70,
#    'LineName': '70',
#    'RouteID': 1104,
#    'ServiceId': 4304,
#    'Course': '04304',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 1153,
#    'FinalStopID': 1467,
#    'FinalStopName': 'Ořešín',
#    'IsInactive': False},
#   {'ID': 21964,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.339706,
#    'Lng': 16.74859,
#    'Bearing': 0,
#    'LineID': 201,
#    'LineName': '201',
#    'RouteID': 71,
#    'ServiceId': 20102,
#    'Course': '20102',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 12319,
#    'FinalStopID': 12317,
#    'FinalStopName': 'Jedovnice, gar.ČAD',
#    'IsInactive': False},
#   {'ID': 1843,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.188965,
#    'Lng': 16.595207,
#    'Bearing': 270,
#    'LineID': 2,
#    'LineName': '2',
#    'RouteID': 1271,
#    'ServiceId': 707,
#    'Course': '00707',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 1721,
#    'FinalStopID': 1706,
#    'FinalStopName': 'Ústř. hřbitov\xa0-\xa0smyčka',
#    'IsInactive': False},
#   {'ID': 2038,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.139656,
#    'Lng': 16.633919,
#    'Bearing': -1,
#    'LineID': 78,
#    'LineName': '78',
#    'RouteID': 1124,
#    'ServiceId': 7805,
#    'Course': '07805',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15130,
#    'FinalStopID': 1809,
#    'FinalStopName': 'Židenice, nádraží',
#    'IsInactive': True},
#   {'ID': 3315,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.197208,
#    'Lng': 16.545874,
#    'Bearing': 0,
#    'LineID': 37,
#    'LineName': '37',
#    'RouteID': 1221,
#    'ServiceId': 3909,
#    'Course': '03909',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 1033,
#    'FinalStopID': 1378,
#    'FinalStopName': 'Mendlovo náměstí',
#    'IsInactive': False},
#   {'ID': 21461,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.851986,
#    'Lng': 16.057043,
#    'Bearing': 225,
#    'LineID': 814,
#    'LineName': '814',
#    'RouteID': 122,
#    'ServiceId': 43204,
#    'Course': '43204',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 18011,
#    'FinalStopID': 18009,
#    'FinalStopName': 'Znojmo, a.n.',
#    'IsInactive': False},
#   {'ID': 21317,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.882023,
#    'Lng': 16.032316,
#    'Bearing': 45,
#    'LineID': 804,
#    'LineName': '804',
#    'RouteID': 159,
#    'ServiceId': 80402,
#    'Course': '80402',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 18047,
#    'FinalStopID': 18048,
#    'FinalStopName': 'Přímětice, hřbitov',
#    'IsInactive': False},
#   {'ID': 1830,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.204777,
#    'Lng': 16.62413,
#    'Bearing': 45,
#    'LineID': 5,
#    'LineName': '5',
#    'RouteID': 1188,
#    'ServiceId': 1108,
#    'Course': '01108',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 1086,
#    'FinalStopID': 1646,
#    'FinalStopName': 'Štefánikova čtvrť',
#    'IsInactive': False},
#   {'ID': 21842,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.949394,
#    'Lng': 17.382042,
#    'Bearing': 225,
#    'LineID': 930,
#    'LineName': '930',
#    'RouteID': 75,
#    'ServiceId': 93201,
#    'Course': '93201',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 19316,
#    'FinalStopID': 19505,
#    'FinalStopName': 'Javorník',
#    'IsInactive': False},
#   {'ID': 1918,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.234806,
#    'Lng': 16.580973,
#    'Bearing': -1,
#    'LineID': 3,
#    'LineName': '3',
#    'RouteID': 1506,
#    'ServiceId': 302,
#    'Course': '00302',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 9430,
#    'FinalStopID': 1659,
#    'FinalStopName': 'Technologický park',
#    'IsInactive': True},
#   {'ID': 21804,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.156178,
#    'Lng': 17.135057,
#    'Bearing': 0,
#    'LineID': 643,
#    'LineName': '643',
#    'RouteID': 16,
#    'ServiceId': 65001,
#    'Course': '65001',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16626,
#    'FinalStopID': 16509,
#    'FinalStopName': 'Nesovice, žel.st.',
#    'IsInactive': False},
#   {'ID': 21236,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.955814,
#    'Lng': 16.70997,
#    'Bearing': 45,
#    'LineID': 165,
#    'LineName': '165',
#    'RouteID': 42,
#    'ServiceId': 16501,
#    'Course': '16501',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 15416,
#    'FinalStopID': 15403,
#    'FinalStopName': 'Hustopeče, a.n.',
#    'IsInactive': False},
#   {'ID': 7051,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.170612,
#    'Lng': 16.585262,
#    'Bearing': -1,
#    'LineID': 69,
#    'LineName': '69',
#    'RouteID': 1106,
#    'ServiceId': 6907,
#    'Course': '06907',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1701,
#    'FinalStopID': 1037,
#    'FinalStopName': 'Bosonohy',
#    'IsInactive': True},
#   {'ID': 2668,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.139519,
#    'Lng': 16.634245,
#    'Bearing': -1,
#    'LineID': 78,
#    'LineName': '78',
#    'RouteID': 1120,
#    'ServiceId': 7804,
#    'Course': '07804',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15130,
#    'FinalStopID': 1809,
#    'FinalStopName': 'Židenice, nádraží',
#    'IsInactive': True},
#   {'ID': 21737,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.508099,
#    'Lng': 16.670156,
#    'Bearing': 225,
#    'LineID': 251,
#    'LineName': '251',
#    'RouteID': 16,
#    'ServiceId': 25102,
#    'Course': '25102',
#    'LF': True,
#    'Delay': 2,
#    'LastStopID': 12742,
#    'FinalStopID': 12635,
#    'FinalStopName': 'Boskovice, aut.st.',
#    'IsInactive': False},
#   {'ID': 3320,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.197582,
#    'Lng': 16.593979,
#    'Bearing': 180,
#    'LineID': 39,
#    'LineName': '39',
#    'RouteID': 1126,
#    'ServiceId': 3901,
#    'Course': '03901',
#    'LF': True,
#    'Delay': 2,
#    'LastStopID': 1712,
#    'FinalStopID': 1013,
#    'FinalStopName': 'Barvičova',
#    'IsInactive': False},
#   {'ID': 1731,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.234863,
#    'Lng': 16.581152,
#    'Bearing': -1,
#    'LineID': 8,
#    'LineName': '8',
#    'RouteID': 1524,
#    'ServiceId': 834,
#    'Course': '00834',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1756,
#    'FinalStopID': 1756,
#    'FinalStopName': 'Vozovna Medlánky',
#    'IsInactive': True},
#   {'ID': 1705,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.190193,
#    'Lng': 16.650742,
#    'Bearing': 135,
#    'LineID': 8,
#    'LineName': '8',
#    'RouteID': 1286,
#    'ServiceId': 806,
#    'Course': '00806',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1291,
#    'FinalStopID': 1384,
#    'FinalStopName': 'Líšeň, Mifkova',
#    'IsInactive': False},
#   {'ID': 21866,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.937992,
#    'Lng': 16.736458,
#    'Bearing': 45,
#    'LineID': 522,
#    'LineName': '522',
#    'RouteID': 42,
#    'ServiceId': 52201,
#    'Course': '52201',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15403,
#    'FinalStopID': 15241,
#    'FinalStopName': 'Židlochovice, žel.st.',
#    'IsInactive': False},
#   {'ID': 3066,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.223251,
#    'Lng': 16.530607,
#    'Bearing': 45,
#    'LineID': 30,
#    'LineName': '30',
#    'RouteID': 1231,
#    'ServiceId': 3007,
#    'Course': '03007',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1752,
#    'FinalStopID': 1143,
#    'FinalStopName': 'Hlavní',
#    'IsInactive': False},
#   {'ID': 7730,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.233715,
#    'Lng': 16.624716,
#    'Bearing': -1,
#    'LineID': 46,
#    'LineName': '46',
#    'RouteID': 1219,
#    'ServiceId': 5704,
#    'Course': '05704',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1132,
#    'FinalStopID': 1100,
#    'FinalStopName': 'Erbenova',
#    'IsInactive': True},
#   {'ID': 21173,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.367779,
#    'Lng': 16.690212,
#    'Bearing': 135,
#    'LineID': 233,
#    'LineName': '233',
#    'RouteID': 15,
#    'ServiceId': 25002,
#    'Course': '25002',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 12378,
#    'FinalStopID': 12622,
#    'FinalStopName': 'Němčice, Dendera',
#    'IsInactive': False},
#   {'ID': 21875,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.995495,
#    'Lng': 16.887995,
#    'Bearing': 315,
#    'LineID': 109,
#    'LineName': '109',
#    'RouteID': 60,
#    'ServiceId': 10901,
#    'Course': '10901',
#    'LF': True,
#    'Delay': 2,
#    'LastStopID': 16466,
#    'FinalStopID': 1696,
#    'FinalStopName': 'Brno, ÚAN Zvonařka',
#    'IsInactive': False},
#   {'ID': 2009,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.214973,
#    'Lng': 16.625969,
#    'Bearing': 90,
#    'LineID': 84,
#    'LineName': '84',
#    'RouteID': 1187,
#    'ServiceId': 7809,
#    'Course': '07809',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1522,
#    'FinalStopID': 1611,
#    'FinalStopName': 'Stará osada',
#    'IsInactive': False},
#   {'ID': 21301,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.747219,
#    'Lng': 16.870502,
#    'Bearing': 0,
#    'LineID': 568,
#    'LineName': '568',
#    'RouteID': 18,
#    'ServiceId': 56003,
#    'Course': '56003',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 15763,
#    'FinalStopID': 15729,
#    'FinalStopName': 'Břeclav, a.n.',
#    'IsInactive': False},
#   {'ID': 1818,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.214436,
#    'Lng': 16.568026,
#    'Bearing': 225,
#    'LineID': 3,
#    'LineName': '3',
#    'RouteID': 1269,
#    'ServiceId': 1001,
#    'Course': '01001',
#    'LF': True,
#    'Delay': 4,
#    'LastStopID': 1544,
#    'FinalStopID': 1217,
#    'FinalStopName': 'Vozovna Komín',
#    'IsInactive': False},
#   {'ID': 21316,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.85376,
#    'Lng': 17.120989,
#    'Bearing': 315,
#    'LineID': 109,
#    'LineName': '109',
#    'RouteID': 62,
#    'ServiceId': 10906,
#    'Course': '10906',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 19001,
#    'FinalStopID': 16545,
#    'FinalStopName': 'Čejč, náměstí',
#    'IsInactive': False},
#   {'ID': 21200,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.313519,
#    'Lng': 16.540606,
#    'Bearing': 225,
#    'LineID': 310,
#    'LineName': '310',
#    'RouteID': 60,
#    'ServiceId': 31001,
#    'Course': '31001',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 13127,
#    'FinalStopID': 13143,
#    'FinalStopName': 'Kuřim, žel.st.',
#    'IsInactive': False},
#   {'ID': 30157,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 5,
#    'LType': 5,
#    'Lat': 49.190149999999996,
#    'Lng': 16.612962,
#    'Bearing': -1,
#    'LineID': 130,
#    'LineName': 'S3',
#    'RouteID': 4959,
#    'ServiceId': 13016,
#    'Course': '13016',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1146,
#    'FinalStopID': 15241,
#    'FinalStopName': 'Židlochovice, žel.st.',
#    'IsInactive': False},
#   {'ID': 21782,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.912575,
#    'Lng': 16.707531,
#    'Bearing': 135,
#    'LineID': 540,
#    'LineName': '540',
#    'RouteID': 40,
#    'ServiceId': 57004,
#    'Course': '57004',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15425,
#    'FinalStopID': 15714,
#    'FinalStopName': 'Mikulov, žel.st.',
#    'IsInactive': False},
#   {'ID': 21665,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.294849,
#    'Lng': 16.342867,
#    'Bearing': 0,
#    'LineID': 312,
#    'LineName': '312',
#    'RouteID': 56,
#    'ServiceId': 31204,
#    'Course': '31204',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 13343,
#    'FinalStopID': 13334,
#    'FinalStopName': 'Tišnov, žel.st.',
#    'IsInactive': False},
#   {'ID': 21755,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.526367,
#    'Lng': 16.614317,
#    'Bearing': 45,
#    'LineID': 254,
#    'LineName': '254',
#    'RouteID': 47,
#    'ServiceId': 25401,
#    'Course': '25401',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 12737,
#    'FinalStopID': 12736,
#    'FinalStopName': 'Letovice, žel.st.',
#    'IsInactive': False},
#   {'ID': 7115,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.158699,
#    'Lng': 16.628117,
#    'Bearing': -1,
#    'LineID': 67,
#    'LineName': '67',
#    'RouteID': 1124,
#    'ServiceId': 6701,
#    'Course': '06701',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 7524,
#    'FinalStopID': 1213,
#    'FinalStopName': 'Jundrov',
#    'IsInactive': True},
#   {'ID': 1106,
#    'IDB': 1617,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.191391,
#    'Lng': 16.612955,
#    'Bearing': 45,
#    'LineID': 12,
#    'LineName': '12',
#    'RouteID': 1299,
#    'ServiceId': 1213,
#    'Course': '01213',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1146,
#    'FinalStopID': 1256,
#    'FinalStopName': 'Komárov',
#    'IsInactive': False},
#   {'ID': 21238,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.954262,
#    'Lng': 17.152433,
#    'Bearing': 90,
#    'LineID': 664,
#    'LineName': '664',
#    'RouteID': 106,
#    'ServiceId': 66204,
#    'Course': '66204',
#    'LF': True,
#    'Delay': 5,
#    'LastStopID': 16802,
#    'FinalStopID': 19001,
#    'FinalStopName': 'Hodonín, a.n.',
#    'IsInactive': False},
#   {'ID': 21145,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.984833,
#    'Lng': 17.187391,
#    'Bearing': 270,
#    'LineID': 665,
#    'LineName': '665',
#    'RouteID': 22,
#    'ServiceId': 66501,
#    'Course': '66501',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 16823,
#    'FinalStopID': 16608,
#    'FinalStopName': 'Kyjov, aut. st.',
#    'IsInactive': False},
#   {'ID': 30294,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 5,
#    'LType': 5,
#    'Lat': 49.191052,
#    'Lng': 16.61206,
#    'Bearing': -1,
#    'LineID': 141,
#    'LineName': 'S41',
#    'RouteID': 4458,
#    'ServiceId': 14159,
#    'Course': '14159',
#    'LF': False,
#    'Delay': 0,
#    'LastStopID': 1146,
#    'FinalStopID': 24501,
#    'FinalStopName': 'Bohutice',
#    'IsInactive': False},
#   {'ID': 1719,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.234058,
#    'Lng': 16.581615,
#    'Bearing': -1,
#    'LineID': 8,
#    'LineName': '8',
#    'RouteID': 1521,
#    'ServiceId': 820,
#    'Course': '00820',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 9430,
#    'FinalStopID': 1756,
#    'FinalStopName': 'Vozovna Medlánky',
#    'IsInactive': True},
#   {'ID': 21482,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.111923,
#    'Lng': 16.729206,
#    'Bearing': 270,
#    'LineID': 610,
#    'LineName': '610',
#    'RouteID': 44,
#    'ServiceId': 61103,
#    'Course': '61103',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16157,
#    'FinalStopID': 16149,
#    'FinalStopName': 'Sokolnice, žel.st.',
#    'IsInactive': False},
#   {'ID': 21986,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.23613,
#    'Lng': 16.777166,
#    'Bearing': 135,
#    'LineID': 701,
#    'LineName': '701',
#    'RouteID': 82,
#    'ServiceId': 70105,
#    'Course': '70105',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 17204,
#    'FinalStopID': 1716,
#    'FinalStopName': 'Úzká',
#    'IsInactive': False},
#   {'ID': 1923,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.183838,
#    'Lng': 16.59506,
#    'Bearing': 0,
#    'LineID': 7,
#    'LineName': '7',
#    'RouteID': 1526,
#    'ServiceId': 928,
#    'Course': '00928',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1430,
#    'FinalStopID': 1343,
#    'FinalStopName': 'Lipová',
#    'IsInactive': False},
#   {'ID': 21240,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.037315,
#    'Lng': 17.104395,
#    'Bearing': 180,
#    'LineID': 642,
#    'LineName': '642',
#    'RouteID': 49,
#    'ServiceId': 64204,
#    'Course': '64204',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 16601,
#    'FinalStopID': 16608,
#    'FinalStopName': 'Kyjov, aut. st.',
#    'IsInactive': False},
#   {'ID': 21592,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.995911,
#    'Lng': 16.858894,
#    'Bearing': 270,
#    'LineID': 541,
#    'LineName': '541',
#    'RouteID': 24,
#    'ServiceId': 54102,
#    'Course': '54102',
#    'LF': True,
#    'Delay': 4,
#    'LastStopID': 16348,
#    'FinalStopID': 15403,
#    'FinalStopName': 'Hustopeče, a.n.',
#    'IsInactive': False},
#   {'ID': 1734,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.191063,
#    'Lng': 16.611971,
#    'Bearing': 225,
#    'LineID': 8,
#    'LineName': '8',
#    'RouteID': 1301,
#    'ServiceId': 824,
#    'Course': '00824',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1146,
#    'FinalStopID': 1429,
#    'FinalStopName': 'Nemocnice Bohunice',
#    'IsInactive': False},
#   {'ID': 3686,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.169392,
#    'Lng': 16.56744,
#    'Bearing': 90,
#    'LineID': 25,
#    'LineName': '25',
#    'RouteID': 1903,
#    'ServiceId': 2507,
#    'Course': '02507',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1472,
#    'FinalStopID': 1217,
#    'FinalStopName': 'Vozovna Komín',
#    'IsInactive': False},
#   {'ID': 21331,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.25515,
#    'Lng': 16.511192,
#    'Bearing': 90,
#    'LineID': 302,
#    'LineName': '302',
#    'RouteID': 66,
#    'ServiceId': 33302,
#    'Course': '33302',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 13138,
#    'FinalStopID': 13143,
#    'FinalStopName': 'Kuřim, žel.st.',
#    'IsInactive': False},
#   {'ID': 21768,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.353661,
#    'Lng': 16.646854,
#    'Bearing': 0,
#    'LineID': 152,
#    'LineName': '152',
#    'RouteID': 1,
#    'ServiceId': 15201,
#    'Course': '15201',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 12342,
#    'FinalStopID': 13143,
#    'FinalStopName': 'Kuřim, žel.st.',
#    'IsInactive': False},
#   {'ID': 21516,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.84634,
#    'Lng': 16.057793,
#    'Bearing': 135,
#    'LineID': 804,
#    'LineName': '804',
#    'RouteID': 156,
#    'ServiceId': 80404,
#    'Course': '80404',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 18021,
#    'FinalStopID': 18038,
#    'FinalStopName': 'Znojmo, Oblekovice, točna',
#    'IsInactive': False},
#   {'ID': 1732,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.234318,
#    'Lng': 16.580704,
#    'Bearing': 180,
#    'LineID': 8,
#    'LineName': '8',
#    'RouteID': 1507,
#    'ServiceId': 818,
#    'Course': '00818',
#    'LF': True,
#    'Delay': 2,
#    'LastStopID': 1756,
#    'FinalStopID': 1756,
#    'FinalStopName': 'Vozovna Medlánky',
#    'IsInactive': False},
#   {'ID': 7677,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.174927,
#    'Lng': 16.62151,
#    'Bearing': 225,
#    'LineID': 49,
#    'LineName': '49',
#    'RouteID': 1142,
#    'ServiceId': 4903,
#    'Course': '04903',
#    'LF': True,
#    'Delay': 2,
#    'LastStopID': 1361,
#    'FinalStopID': 15130,
#    'FinalStopName': 'Modřice, Olympia',
#    'IsInactive': False},
#   {'ID': 1738,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 47,
#    'Lng': 16.60791,
#    'Bearing': 180,
#    'LineID': 8,
#    'LineName': '8',
#    'RouteID': 1526,
#    'ServiceId': 802,
#    'Course': '00802',
# ...
#   {'ID': 21201,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.49255,
#    'Lng': 16.588165,
#    'Bearing': 0,
#    'LineID': 256,
#    'LineName': '256',
#    'RouteID': 63,
#    'ServiceId': 23402,
#    'Course': '23402',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 12036,
#    'FinalStopID': 12690,
#    'FinalStopName': 'Kunštát, nám.',
#    'IsInactive': False},
#   {'ID': 21023,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.319,
#    'Lng': 17.026119,
#    'Bearing': 135,
#    'LineID': 755,
#    'LineName': '755',
#    'RouteID': 106,
#    'ServiceId': 75101,
#    'Course': '75101',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 17530,
#    'FinalStopID': 17423,
#    'FinalStopName': 'Vyškov, a.n.',
#    'IsInactive': False},
#   {'ID': 7717,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.228416,
#    'Lng': 16.530981,
#    'Bearing': -1,
#    'LineID': 54,
#    'LineName': '54',
#    'RouteID': 1136,
#    'ServiceId': 5214,
#    'Course': '05214',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1796,
#    'FinalStopID': 1559,
#    'FinalStopName': 'Říčanská',
#    'IsInactive': True},
#   {'ID': 7715,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.227425,
#    'Lng': 16.530981,
#    'Bearing': 180,
#    'LineID': 54,
#    'LineName': '54',
#    'RouteID': 1134,
#    'ServiceId': 5218,
#    'Course': '05218',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1796,
#    'FinalStopID': 1559,
#    'FinalStopName': 'Říčanská',
#    'IsInactive': False},
#   {'ID': 7707,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.206623,
#    'Lng': 16.635239,
#    'Bearing': -1,
#    'LineID': 899,
#    'LineName': 'FEI',
#    'RouteID': 1040,
#    'ServiceId': 30062,
#    'Course': '30062',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 7510,
#    'FinalStopID': 1357,
#    'FinalStopName': 'Malinovského náměstí',
#    'IsInactive': True},
#   {'ID': 21053,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.829124,
#    'Lng': 16.399508,
#    'Bearing': 0,
#    'LineID': 174,
#    'LineName': '174',
#    'RouteID': 24,
#    'ServiceId': 17401,
#    'Course': '17401',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15631,
#    'FinalStopID': 15714,
#    'FinalStopName': 'Mikulov, žel.st.',
#    'IsInactive': False},
#   {'ID': 7702,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.20956,
#    'Lng': 16.61578,
#    'Bearing': 225,
#    'LineID': 46,
#    'LineName': '46',
#    'RouteID': 106,
#    'ServiceId': 9302,
#    'Course': '09302',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1100,
#    'FinalStopID': 1132,
#    'FinalStopName': 'Lesná, Haškova',
#    'IsInactive': False},
#   {'ID': 7520,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.207829,
#    'Lng': 16.583464,
#    'Bearing': 45,
#    'LineID': 68,
#    'LineName': '68',
#    'RouteID': 1123,
#    'ServiceId': 6508,
#    'Course': '06508',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1371,
#    'FinalStopID': 1652,
#    'FinalStopName': 'Šumavská',
#    'IsInactive': False},
#   {'ID': 21448,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 49.140759,
#    'Lng': 16.632809,
#    'Bearing': -1,
#    'LineID': 503,
#    'LineName': 'OLY',
#    'RouteID': 61,
#    'ServiceId': 42104,
#    'Course': '42104',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15130,
#    'FinalStopID': 1716,
#    'FinalStopName': 'Úzká',
#    'IsInactive': False},
#   {'ID': 7101,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.189438,
#    'Lng': 16.61425,
#    'Bearing': 270,
#    'LineID': 77,
#    'LineName': '77',
#    'RouteID': 1155,
#    'ServiceId': 7705,
#    'Course': '07705',
#    'LF': True,
#    'Delay': 2,
#    'LastStopID': 1011,
#    'FinalStopID': 1716,
#    'FinalStopName': 'Úzká',
#    'IsInactive': False},
#   {'ID': 7100,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.243416,
#    'Lng': 16.626562,
#    'Bearing': 135,
#    'LineID': 57,
#    'LineName': '57',
#    'RouteID': 1231,
#    'ServiceId': 5705,
#    'Course': '05705',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1479,
#    'FinalStopID': 1477,
#    'FinalStopName': 'Pálavské náměstí',
#    'IsInactive': False},
#   {'ID': 7089,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.203011,
#    'Lng': 16.716301,
#    'Bearing': 90,
#    'LineID': 55,
#    'LineName': '55',
#    'RouteID': 1112,
#    'ServiceId': 5801,
#    'Course': '05801',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1362,
#    'FinalStopID': 1809,
#    'FinalStopName': 'Židenice, nádraží',
#    'IsInactive': False},
#   {'ID': 30063,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 5,
#    'LType': 5,
#    'Lat': 49.190338,
#    'Lng': 16.612522,
#    'Bearing': -1,
#    'LineID': 140,
#    'LineName': 'S4',
#    'RouteID': 4856,
#    'ServiceId': 14056,
#    'Course': '14056',
#    'LF': False,
#    'Delay': 0,
#    'LastStopID': 1146,
#    'FinalStopID': 31012,
#    'FinalStopName': 'Třebíč',
#    'IsInactive': False},
#   {'ID': 7060,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 4,
#    'Lat': 49.228271,
#    'Lng': 16.65262,
#    'Bearing': 270,
#    'LineID': 785,
#    'LineName': 'x45',
#    'RouteID': 1111,
#    'ServiceId': 5811,
#    'Course': '05811',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1014,
#    'FinalStopID': 1611,
#    'FinalStopName': 'Stará osada',
#    'IsInactive': False},
#   {'ID': 7048,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.142284,
#    'Lng': 16.63269,
#    'Bearing': 315,
#    'LineID': 49,
#    'LineName': '49',
#    'RouteID': 1135,
#    'ServiceId': 4911,
#    'Course': '04911',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15130,
#    'FinalStopID': 1716,
#    'FinalStopName': 'Úzká',
#    'IsInactive': False},
#   {'ID': 7044,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.190895,
#    'Lng': 16.594547,
#    'Bearing': 270,
#    'LineID': 52,
#    'LineName': '52',
#    'RouteID': 1133,
#    'ServiceId': 5213,
#    'Course': '05213',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1378,
#    'FinalStopID': 1796,
#    'FinalStopName': 'Bystrc, ZOO',
#    'IsInactive': False},
#   {'ID': 30220,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 5,
#    'LType': 5,
#    'Lat': 48.917096,
#    'Lng': 17.248876000000003,
#    'Bearing': 225,
#    'LineID': 139,
#    'LineName': 'S9',
#    'RouteID': 4222,
#    'ServiceId': 13902,
#    'Course': '13902',
#    'LF': False,
#    'Delay': 4,
#    'LastStopID': 16905,
#    'FinalStopID': 15729,
#    'FinalStopName': 'Břeclav, a.n.',
#    'IsInactive': False},
#   {'ID': 7033,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.195816,
#    'Lng': 16.652092,
#    'Bearing': 270,
#    'LineID': 58,
#    'LineName': '58',
#    'RouteID': 101,
#    'ServiceId': 9701,
#    'Course': '09701',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1212,
#    'FinalStopID': 1611,
#    'FinalStopName': 'Stará osada',
#    'IsInactive': False},
#   {'ID': 7008,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.191319,
#    'Lng': 16.626375,
#    'Bearing': 270,
#    'LineID': 64,
#    'LineName': '64',
#    'RouteID': 1109,
#    'ServiceId': 6405,
#    'Course': '06405',
#    'LF': True,
#    'Delay': 2,
#    'LastStopID': 1814,
#    'FinalStopID': 1182,
#    'FinalStopName': 'Chrlice, smyčka',
#    'IsInactive': False},
#   {'ID': 3681,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.218189,
#    'Lng': 16.628988,
#    'Bearing': 0,
#    'LineID': 25,
#    'LineName': '25',
#    'RouteID': 1228,
#    'ServiceId': 2523,
#    'Course': '02523',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1646,
#    'FinalStopID': 1472,
#    'FinalStopName': 'Osová',
#    'IsInactive': False},
#   {'ID': 3679,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.209187,
#    'Lng': 16.688614,
#    'Bearing': 180,
#    'LineID': 27,
#    'LineName': '27',
#    'RouteID': 1234,
#    'ServiceId': 2703,
#    'Course': '02703',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1208,
#    'FinalStopID': 1611,
#    'FinalStopName': 'Stará osada',
#    'IsInactive': False},
#   {'ID': 3654,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.181511,
#    'Lng': 16.690332,
#    'Bearing': 0,
#    'LineID': 33,
#    'LineName': '33',
#    'RouteID': 1198,
#    'ServiceId': 3303,
#    'Course': '03303',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 1577,
#    'FinalStopID': 1577,
#    'FinalStopName': 'Slatina, sídliště',
#    'IsInactive': False},
#   {'ID': 3649,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.181683,
#    'Lng': 16.670191,
#    'Bearing': 315,
#    'LineID': 31,
#    'LineName': '31',
#    'RouteID': 1199,
#    'ServiceId': 3307,
#    'Course': '03307',
#    'LF': True,
#    'Delay': 3,
#    'LastStopID': 1741,
#    'FinalStopID': 1146,
#    'FinalStopName': 'Hlavní nádraží',
#    'IsInactive': False},
#   {'ID': 30041,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 5,
#    'LType': 5,
#    'Lat': 49.167482,
#    'Lng': 16.60692,
#    'Bearing': 180,
#    'LineID': 141,
#    'LineName': 'S41',
#    'RouteID': 4454,
#    'ServiceId': 14155,
#    'Course': '14155',
#    'LF': False,
#    'Delay': 2,
#    'LastStopID': 11002,
#    'FinalStopID': 24501,
#    'FinalStopName': 'Bohutice',
#    'IsInactive': False},
#   {'ID': 3311,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.216171,
#    'Lng': 16.559229,
#    'Bearing': -1,
#    'LineID': 32,
#    'LineName': '32',
#    'RouteID': 4903,
#    'ServiceId': 3205,
#    'Course': '03205',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1143,
#    'FinalStopID': 1143,
#    'FinalStopName': 'Hlavní',
#    'IsInactive': True},
#   {'ID': 3062,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.221046,
#    'Lng': 16.58378,
#    'Bearing': 225,
#    'LineID': 32,
#    'LineName': '32',
#    'RouteID': 4907,
#    'ServiceId': 3405,
#    'Course': '03405',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1567,
#    'FinalStopID': 1143,
#    'FinalStopName': 'Hlavní',
#    'IsInactive': False},
#   {'ID': 3059,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 1,
#    'LType': 1,
#    'Lat': 49.220314,
#    'Lng': 16.571655,
#    'Bearing': 315,
#    'LineID': 34,
#    'LineName': '34',
#    'RouteID': 1153,
#    'ServiceId': 3407,
#    'Course': '03407',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1766,
#    'FinalStopID': 1073,
#    'FinalStopName': 'Česká',
#    'IsInactive': False},
#   {'ID': 2679,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.21806,
#    'Lng': 16.509781,
#    'Bearing': 135,
#    'LineID': 790,
#    'LineName': 'E50',
#    'RouteID': 1054,
#    'ServiceId': 5032,
#    'Course': '05032',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1102,
#    'FinalStopID': 1581,
#    'FinalStopName': 'Areál Slatina',
#    'IsInactive': False},
#   {'ID': 2682,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.239876,
#    'Lng': 16.588583,
#    'Bearing': 180,
#    'LineID': 70,
#    'LineName': '70',
#    'RouteID': 1115,
#    'ServiceId': 4208,
#    'Course': '04208',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1338,
#    'FinalStopID': 1566,
#    'FinalStopName': 'Semilasso',
#    'IsInactive': False},
#   {'ID': 2675,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.19891,
#    'Lng': 16.695068,
#    'Bearing': 180,
#    'LineID': 78,
#    'LineName': '78',
#    'RouteID': 1123,
#    'ServiceId': 7810,
#    'Course': '07810',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1406,
#    'FinalStopID': 15130,
#    'FinalStopName': 'Modřice, Olympia',
#    'IsInactive': False},
#   {'ID': 2633,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.139389,
#    'Lng': 16.63575,
#    'Bearing': 270,
#    'LineID': 78,
#    'LineName': '78',
#    'RouteID': 101,
#    'ServiceId': 9601,
#    'Course': '09601',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 15186,
#    'FinalStopID': 15130,
#    'FinalStopName': 'Modřice, Olympia',
#    'IsInactive': False},
#   {'ID': 30206,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 5,
#    'LType': 5,
#    'Lat': 48.853415999999996,
#    'Lng': 16.059058999999998,
#    'Bearing': -1,
#    'LineID': 137,
#    'LineName': 'S82',
#    'RouteID': 2273,
#    'ServiceId': 13709,
#    'Course': '13709',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 18009,
#    'FinalStopID': 31034,
#    'FinalStopName': 'Retz',
#    'IsInactive': False},
#   {'ID': 30196,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 5,
#    'LType': 5,
#    'Lat': 48.96944,
#    'Lng': 17.263431,
#    'Bearing': 270,
#    'LineID': 148,
#    'LineName': 'S61',
#    'RouteID': 24160,
#    'ServiceId': 14801,
#    'Course': '14801',
#    'LF': False,
#    'Delay': 2,
#    'LastStopID': 16908,
#    'FinalStopID': 16908,
#    'FinalStopName': 'Bzenec, žel.st.',
#    'IsInactive': False},
#   {'ID': 2036,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 2,
#    'LType': 2,
#    'Lat': 49.202305,
#    'Lng': 16.642017,
#    'Bearing': 45,
#    'LineID': 78,
#    'LineName': '78',
#    'RouteID': 1127,
#    'ServiceId': 8411,
#    'Course': '08411',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1611,
#    'FinalStopID': 15130,
#    'FinalStopName': 'Modřice, Olympia',
#    'IsInactive': False},
#   {'ID': 30153,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 5,
#    'LType': 5,
#    'Lat': 48.906375,
#    'Lng': 16.726117,
#    'Bearing': 135,
#    'LineID': 135,
#    'LineName': 'R13',
#    'RouteID': 831,
#    'ServiceId': 13515,
#    'Course': '13515',
#    'LF': False,
#    'Delay': 2,
#    'LastStopID': 15425,
#    'FinalStopID': 19001,
#    'FinalStopName': 'Hodonín, a.n.',
#    'IsInactive': False},
#   {'ID': 21621,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 4,
#    'LType': 4,
#    'Lat': 48.866081,
#    'Lng': 16.559103,
#    'Bearing': 315,
#    'LineID': 105,
#    'LineName': '105',
#    'RouteID': 26,
#    'ServiceId': 10501,
#    'Course': '10501',
#    'LF': True,
#    'Delay': 5,
#    'LastStopID': 15543,
#    'FinalStopID': 1696,
#    'FinalStopName': 'Brno, ÚAN Zvonařka',
#    'IsInactive': False},
#   {'ID': 1934,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.234009,
#    'Lng': 16.581396,
#    'Bearing': 90,
#    'LineID': 6,
#    'LineName': '6',
#    'RouteID': 1514,
#    'ServiceId': 606,
#    'Course': '00606',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1756,
#    'FinalStopID': 1756,
#    'FinalStopName': 'Vozovna Medlánky',
#    'IsInactive': False},
#   {'ID': 1915,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.168205,
#    'Lng': 16.562801,
#    'Bearing': 270,
#    'LineID': 7,
#    'LineName': '7',
#    'RouteID': 1137,
#    'ServiceId': 914,
#    'Course': '00914',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1472,
#    'FinalStopID': 1616,
#    'FinalStopName': 'Starý Lískovec',
#    'IsInactive': False},
#   {'ID': 1846,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.192448,
#    'Lng': 16.573332,
#    'Bearing': -1,
#    'LineID': 7,
#    'LineName': '7',
#    'RouteID': 1524,
#    'ServiceId': 711,
#    'Course': '00711',
#    'LF': True,
#    'Delay': 4,
#    'LastStopID': 1343,
#    'FinalStopID': 1343,
#    'FinalStopName': 'Lipová',
#    'IsInactive': True},
#   {'ID': 1850,
#    'IDB': 0,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.21582,
#    'Lng': 16.557251,
#    'Bearing': -1,
#    'LineID': 3,
#    'LineName': '3',
#    'RouteID': 1270,
#    'ServiceId': 703,
#    'Course': '00703',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1633,
#    'FinalStopID': 1611,
#    'FinalStopName': 'Stará osada',
#    'IsInactive': True},
#   {'ID': 1128,
#    'IDB': 1575,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.192829,
#    'Lng': 16.572201,
#    'Bearing': -1,
#    'LineID': 12,
#    'LineName': '12',
#    'RouteID': 1517,
#    'ServiceId': 1203,
#    'Course': '01203',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 9410,
#    'FinalStopID': 1343,
#    'FinalStopName': 'Lipová',
#    'IsInactive': True},
#   {'ID': 1120,
#    'IDB': 1627,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.232227,
#    'Lng': 16.576513,
#    'Bearing': -1,
#    'LineID': 12,
#    'LineName': '12',
#    'RouteID': 1303,
#    'ServiceId': 1217,
#    'Course': '01217',
#    'LF': True,
#    'Delay': 0,
#    'LastStopID': 1659,
#    'FinalStopID': 1256,
#    'FinalStopName': 'Komárov',
#    'IsInactive': False},
#   {'ID': 1108,
#    'IDB': 1497,
#    'IDC': 0,
#    'VType': 0,
#    'LType': 0,
#    'Lat': 49.220875,
#    'Lng': 16.520346,
#    'Bearing': 270,
#    'LineID': 1,
#    'LineName': '1',
#    'RouteID': 1298,
#    'ServiceId': 127,
#    'Course': '00127',
#    'LF': True,
#    'Delay': 1,
#    'LastStopID': 1312,
#    'FinalStopID': 1553,
#    'FinalStopName': 'Řečkovice',
#    'IsInactive': False}]}

# %%
# Výpis data a času vytvoření
timestamp = data['LastUpdate']
# print(timestamp)
print(f"Datum: {timestamp[:10]}, čas: {timestamp[11:11+8]}")
# Out:
# Datum: 2024-04-24, čas: 21:00:32

# %% [markdown]
# ## 1. Řešení se slovníky:

# %%
vehicles = data['Vehicles']

# Počet všech vozidel
pocet_vozidel = len(vehicles)

# Inicializace proměnných
hranice_maleho_zpozdeni = 5

pocet_neaktivnich = 0
pocet_nizkopodlaznich_regionalnich_vlaku = 0
pocet_zpozdenych_nad5min = 0
zpozdeni_celkem = 0
pocty_vozidel_brno = {
    'pocet_tramvaji': 0,
    'pocet_trolejbusu': 0,
    'pocet_autobusu': 0,
}

# Procházení slovníku a sbírání dat
for vehicle in vehicles:

    # Počítadlo neaktivních vozidel
    if vehicle['IsInactive']:
        pocet_neaktivnich += 1
    
    # Počítadlo zpožděných nad 5 minut
    if vehicle['Delay'] > hranice_maleho_zpozdeni:
        pocet_zpozdenych_nad5min += 1

    # Sčítadlo všech zpoždění
    zpozdeni_celkem += vehicle['Delay']

    # Počítání vozidel podle typu
    lineId = vehicle['LineID']
    if lineId <= 12:
        pocty_vozidel_brno['pocet_tramvaji'] += 1
    elif 20 <= lineId <= 39:
        pocty_vozidel_brno['pocet_trolejbusu'] += 1
    elif 40 <= lineId <= 99:
        pocty_vozidel_brno['pocet_autobusu'] += 1

    # Počítání aktivních regionálních vlaků
    if (vehicle['LF']) and ('R' in vehicle['LineName'] or 'S' in vehicle['LineName']):
        pocet_nizkopodlaznich_regionalnich_vlaku += 1

# Výpočty ke zpoždění
procento_zpozdenych_nad5min = pocet_zpozdenych_nad5min / pocet_vozidel * 100
zpozdeni_prumer = zpozdeni_celkem / pocet_vozidel

# Výstupy pro řešení se slovníky
print(f"Celkem vozidel: {pocet_vozidel}")
print(f"Neaktivních vozidel: {pocet_neaktivnich}")
print(f"Vozidel zpožděných více než 5 minut je {pocet_zpozdenych_nad5min} ({procento_zpozdenych_nad5min:.2f} %).")

print(f"Průměrné zpoždění je {zpozdeni_prumer:.2f} minut")
print(f"Počet nízkopodlažních regionálních vlaků je {pocet_nizkopodlaznich_regionalnich_vlaku}")
print(f"Brněnská vozidla: {pocty_vozidel_brno}.")

# Uložení výstupu
with open("pocty_vozidel_slovniky.json", mode="w", encoding="utf-8") as file:
    json.dump(pocty_vozidel_brno, file, ensure_ascii=False, indent=4)
# Out:
# Celkem vozidel: 430
# Neaktivních vozidel: 64
# Vozidel zpožděných více než 5 minut je 19 (4.42 %).
# Průměrné zpoždění je 1.57 minut
# Počet nízkopodlažních regionálních vlaků je 19
# Brněnská vozidla: {'pocet_tramvaji': 99, 'pocet_trolejbusu': 42, 'pocet_autobusu': 90}.

# %% [markdown]
# ## 2. Řešení pandas:

# %%
import pandas

vehicles_df = pandas.DataFrame.from_dict(data['Vehicles'])
vehicles_df.head()
# Out:
#       ID   IDB  IDC  VType  LType        Lat        Lng  Bearing  LineID  \
# 0   1922     0    0      0      0  49.192734  16.572811       -1       2
# 1  21571     0    0      4      4  48.853413  17.109982       45     901
# 2  21136     0    0      4      4  48.755608  16.850769      225     571
# 3   1925     0    0      0      0  49.191319  16.612240       45       2
# 4   1094  1523    0      0      0  49.231365  16.577042      315      12
#
#   LineName  RouteID  ServiceId Course    LF  Delay  LastStopID  FinalStopID  \
# 0        2     1505        212  00212  True      0        9410         1343
# 1      901       75      90301  90301  True      0       19019        19008
# 2      571       23      57101  57101  True      0       15745        15801
# 3        2     1268        206  00206  True      0        1146         1611
# 4       12     1306       1221  01221  True      2        1659         1659
#
#         FinalStopName  IsInactive
# 0              Lipová        True
# 1   Hodonín, nem.láz.       False
# 2   Valtice, aut. st.       False
# 3         Stará osada       False
# 4  Technologický park       False

# %%
# Počet všech vozidel
# pocet_vozidel = vehicles_df.shape[0]
pocet_vozidel = len(vehicles_df)

# Počet vozidel, která mají pauzu
neaktivni_vozidla = vehicles_df[vehicles_df["IsInactive"]]
pocet_neaktivnich = neaktivni_vozidla.shape[0]
# pocet_neaktivnich = vehicles_df["IsInactive"].sum()

# Počet vozidel se zpožděním větším než 5 minut
zpozdena_nad5min = vehicles_df[vehicles_df["Delay"] > 5]
pocet_zpozdenych_nad5min = zpozdena_nad5min.shape[0]
procento_zpozdenych_nad5min = pocet_zpozdenych_nad5min / pocet_vozidel * 100

# Průměr zpoždění
zpozdeni_celkem = vehicles_df["Delay"].sum()
zpozdeni_prumer = zpozdeni_celkem / pocet_vozidel

# Počet nízkopodlažních regionálních vlaků
# nizkopodlazni_regionalni_vlaky = vehicles_df[(vehicles_df["LF"]) & (vehicles_df["LineName"].str.contains("R") | vehicles_df["LineName"].str.contains("S"))].shape[0]
nizkopodlazni_regionalni_vlaky = vehicles_df[(vehicles_df["LF"]) & (vehicles_df["LineName"].str.contains("R|S"))]
pocet_nizkopodlaznich_regionalnich_vlaku = nizkopodlazni_regionalni_vlaky.shape[0]


# Výběr vozidel podle typu - složená podmínka
# tramvaje = vehicles_df[(vehicles_df['LineID'] >= 1) & (vehicles_df['LineID'] <= 12)]
# trolejbusy = vehicles_df[(vehicles_df['LineID'] >= 20) & (vehicles_df['LineID'] <= 39)]
# autobusy = vehicles_df[(vehicles_df['LineID'] >= 40) & (vehicles_df['LineID'] <= 99)]

# Výběr vozidel podle typu - metoda between
tramvaje = vehicles_df[vehicles_df['LineID'].between(1,12)]
trolejbusy = vehicles_df[vehicles_df['LineID'].between(20,39)]
autobusy = vehicles_df[vehicles_df['LineID'].between(40,99)]

pocty_vozidel_brno = {
    "pocet_tramvaji": len(tramvaje),
    "pocet_trolejbusu": len(trolejbusy),
    "pocet_autobusu": len(autobusy),
}
# ... případně lze rovnou sčítat řádky splňující podmínku jako např. vehicles_df['LineID'].between(1,12).sum()


# Výstupy pro řešení s pandas
print(f"Celkem vozidel: {pocet_vozidel}")
print(f"Neaktivních vozidel: {pocet_neaktivnich}")
print(f"Vozidel zpožděných více než 5 minut je {pocet_zpozdenych_nad5min} ({procento_zpozdenych_nad5min:.2f} %).")

print(f"Průměrné zpoždění je {zpozdeni_prumer:.2f} minut")
print(f"Počet nízkopodlažních regionálních vlaků je {pocet_nizkopodlaznich_regionalnich_vlaku}")
print(f"Brněnská vozidla: {pocty_vozidel_brno}.")

# Uložení výstupu
with open("pocty_vozidel_pandas.json", mode="w", encoding="utf-8") as file:
    json.dump(pocty_vozidel_brno, file, ensure_ascii=False, indent=4)
# Out:
# Celkem vozidel: 430
# Neaktivních vozidel: 64
# Vozidel zpožděných více než 5 minut je 19 (4.42 %).
# Průměrné zpoždění je 1.57 minut
# Počet nízkopodlažních regionálních vlaků je 19
# Brněnská vozidla: {'pocet_tramvaji': 99, 'pocet_trolejbusu': 42, 'pocet_autobusu': 90}.
